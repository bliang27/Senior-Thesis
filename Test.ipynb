# %%
# %load_ext autoreload
# %autoreload 2
import os; import sys; sys.path.append('../')
import pandas as pd
import tqdm
import warnings
import copy
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
## Configure file and folder names
datafolder = "../data"
spadl_h5 = os.path.join(datafolder,"spadl-statsbomb.h5")
predictions_h5 = os.path.join(datafolder,"predictions.h5")

# %%
games = pd.read_hdf(spadl_h5,"games")
games = games[games.competition_name == "FIFA World Cup"]
print("nb of games:", len(games))
# Out:
# nb of games: 64

# %%
players = pd.read_hdf(spadl_h5,"players")
teams = pd.read_hdf(spadl_h5,"teams")
actiontypes = pd.read_hdf(spadl_h5, "actiontypes")
bodyparts = pd.read_hdf(spadl_h5, "bodyparts")
results = pd.read_hdf(spadl_h5, "results")

A = []
for game in tqdm.tqdm(list(games.itertuples())):
    actions = pd.read_hdf(spadl_h5,f"actions/game_{game.game_id}")
    actions = (
        actions.merge(actiontypes)
        .merge(results)
        .merge(bodyparts)
        .merge(players,"left",on="player_id")
        .merge(teams,"left",on="team_id")
        .sort_values(["period_id", "time_seconds", "timestamp"])
        .reset_index(drop=True)
    )

    A.append(pd.concat([actions],axis=1))
A = pd.concat(A).sort_values(["game_id","period_id", "time_seconds", "timestamp"]).reset_index(drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 64/64 [00:01<00:00, 38.17it/s]

# %% [markdown]
# # Types of Actions

# %%
seen = []
test = A["type_name"]
for t in test:
    if t not in seen:
        seen.append(t)
        
print(seen)
# Out:
# ['pass', 'dribble', 'tackle', 'throw_in', 'interception', 'foul', 'take_on', 'corner_crossed', 'clearance', 'freekick_crossed', 'bad_touch', 'shot', 'cross', 'freekick_short', 'goalkick', 'keeper_claim', 'keeper_save', 'shot_freekick', 'corner_short', 'shot_penalty', 'keeper_punch']

# %% [markdown]
# # Types of Results

# %%
seen = []
test = A["result_name"]
for t in test:
    if t not in seen:
        seen.append(t)
        
print(seen)
# Out:
# ['success', 'fail', 'offside', 'yellow_card', 'owngoal', 'red_card']

# %%
def change_possession(action, action_team, possession_team, result):
    key_change = ['pass', 'dribble', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 'shot', 
                  'freekick_short', 'goalkick', 'corner_short', 'shot_penalty']
    success_change = ['tackle', 'interception', 'take_on', 'clearance', 'keeper_claim', 'keeper_save', 
                      'keeper_punch']
    
    if action in key_change:
        if (action_team != possession_team):
            return True
    if action in success_change:
        if (action_team != possession_team):
            if result == 'success':
                return True
            
        
    return False

# %%
all_possessions = []
curr_possession = []
possessing_team = A.loc[0]["team_id"]
for i in range(len(A)):
    action = A.loc[i]["type_name"]
    action_team = A.loc[i]["team_id"]
    result = A.loc[i]["result_name"]
    if change_possession(action, action_team, possessing_team, result):
        possessing_team = action_team
        all_possessions.append(copy.deepcopy(curr_possession))
        curr_possession = []
    
    curr_possession.append(A.loc[i])
    
#all_possessions = pd.concat(all_possessions)
#print(all_possessions[-1])

# %%
players = pd.read_hdf(spadl_h5,"players")
teams = pd.read_hdf(spadl_h5,"teams")
actiontypes = pd.read_hdf(spadl_h5, "actiontypes")
bodyparts = pd.read_hdf(spadl_h5, "bodyparts")
results = pd.read_hdf(spadl_h5, "results")

B = []
game = list(games.itertuples())[0]
#for game in tqdm.tqdm(list(games.itertuples()))[0]:
actions = pd.read_hdf(spadl_h5,f"actions/game_{game.game_id}")
actions = (
    actions.merge(actiontypes)
    .merge(results)
    .merge(bodyparts)
    .merge(players,"left",on="player_id")
    .merge(teams,"left",on="team_id")
    .sort_values(["period_id", "time_seconds", "timestamp"])
    .reset_index(drop=True)
)

#preds = pd.read_hdf(predictions_h5,f"game_{game.game_id}")
#values = vaep.value(actions,preds.scores,preds.concedes)
B.append(pd.concat([actions],axis=1))
B = pd.concat(B).sort_values(["game_id","period_id", "time_seconds", "timestamp"]).reset_index(drop=True)

# %%
all_possessions = []
curr_possession = []
possessing_team = B.loc[0]["team_id"]
for i in range(len(B)):
    action = B.loc[i]["type_name"]
    action_team = B.loc[i]["team_id"]
    result = B.loc[i]["result_name"]
    if change_possession(action, action_team, possessing_team, result):
        possessing_team = action_team
        all_possessions.append(copy.deepcopy(curr_possession))
        curr_possession = []
    
    curr_possession.append(B.loc[i])
    
#all_possessions = pd.concat(all_possessions)
#print(all_possessions)

# %%
#B.to_csv('test1.csv')
#print(all_possessions[0])

# %%
import networkx as nx
import numpy as np
from collections import Counter

# %%
def players_in_game(B):
    team_id = B.loc[0]["team_id"]
    team1 = []
    team2 = []
    players = {}
    for i in range(len(B)):
        player = B.loc[i]["player_name"]
        if players.get(player) == None:
            players[player] = [0,0]
            if B.loc[i]["team_id"] == team_id:
                team1.append(player)
            else:
                team2.append(player)
            
    return players, team1, team2

# %%
p_test = all_possessions[0]

# %%
game_centrality, team1, team2 = players_in_game(B)
avg_centrality = copy.deepcopy(game_centrality)
print(game_centrality)
# Out:
# {'Antoine Griezmann': [0, 0], 'Raphaël Varane': [0, 0], 'Benjamin Pavard': [0, 0], 'Kylian Mbappé Lottin': [0, 0], 'Toby Alderweireld': [0, 0], 'Kevin De Bruyne': [0, 0], 'Blaise Matuidi': [0, 0], 'Jan Vertonghen': [0, 0], 'Paul Pogba': [0, 0], 'Axel Witsel': [0, 0], 'Samuel Yves Umtiti': [0, 0], 'Lucas Hernández Pi': [0, 0], 'N"Golo Kanté': [0, 0], 'Hugo Lloris': [0, 0], 'Olivier Giroud': [0, 0], 'Eden Hazard': [0, 0], 'Nacer Chadli': [0, 0], 'Moussa Sidi Yaya Dembélé': [0, 0], 'Marouane Fellaini-Bakkioui': [0, 0], 'Vincent Kompany': [0, 0], 'Thibaut Courtois': [0, 0], 'Romelu Lukaku Menama': [0, 0], 'Dries Mertens': [0, 0], 'Yannick Ferreira Carrasco': [0, 0], 'Steven N"Kemboanza Mike Christopher Nzonzi': [0, 0], 'Corentin Tolisso': [0, 0]}

# %%
def players_in_pos(pos):
    contribution = ['pass', 'dribble', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 'shot', 
                  'freekick_short', 'goalkick', 'corner_short', 'shot_penalty']
    
    players = []
    for play in pos:
        action = play["type_name"]
        player = play["player_name"]
        if action in contribution and result == 'success':
            if player not in players:
                players.append(player)
            
    return players

# %%
players_in_pos(p_test)
# Out:
# ['Antoine Griezmann',
#  'Raphaël Varane',
#  'Benjamin Pavard',
#  'Kylian Mbappé Lottin']

# %%
contribution = ['pass', 'dribble', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 'shot', 
                  'freekick_short', 'goalkick', 'corner_short', 'shot_penalty']

pos_players = []

for play in p_test:
    player = play['player_name']
    if play['type_name'] in contribution and play['result_name'] == 'success':
        if player not in pos_players:
            pos_players.append(player)
            
print(pos_players)
# Out:
# ['Antoine Griezmann', 'Raphaël Varane', 'Benjamin Pavard', 'Kylian Mbappé Lottin']

# %%
for pos in all_possessions:
    players = players_in_pos(pos)

    shot = False
    for play in pos:
        if play['type_name'] == 'shot':
            shot = True
            
    if shot:
        for player in players:
            game_centrality[player][0] += 1
            
        for player in game_centrality.keys():
            game_centrality[player][1] += 1

# %%
avg_cont = {}
for key in game_centrality.keys():
    pos_num = game_centrality[key][1]
    average_centrality = game_centrality[key][0] / pos_num if pos_num > 0 else 0
    #print(average_centrality)
    avg_cont[key] = average_centrality
    #print(avg_centrality[key])

# %%
from collections import OrderedDict
dd = OrderedDict(sorted(avg_cont.items(), key=lambda x: x[1], reverse=True))
for key in dd:
    print(key + ": " + str(dd[key]))
# Out:
# Antoine Griezmann: 0.48
# Kylian Mbappé Lottin: 0.36
# N"Golo Kanté: 0.36
# Paul Pogba: 0.32
# Olivier Giroud: 0.32
# Toby Alderweireld: 0.28
# Blaise Matuidi: 0.24
# Lucas Hernández Pi: 0.24
# Benjamin Pavard: 0.2
# Axel Witsel: 0.2
# Samuel Yves Umtiti: 0.2
# Vincent Kompany: 0.2
# Raphaël Varane: 0.16
# Kevin De Bruyne: 0.16
# Eden Hazard: 0.16
# Nacer Chadli: 0.16
# Jan Vertonghen: 0.12
# Moussa Sidi Yaya Dembélé: 0.12
# Marouane Fellaini-Bakkioui: 0.12
# Dries Mertens: 0.08
# Hugo Lloris: 0.04
# Romelu Lukaku Menama: 0.04
# Corentin Tolisso: 0.04
# Thibaut Courtois: 0.0
# Yannick Ferreira Carrasco: 0.0
# Steven N"Kemboanza Mike Christopher Nzonzi: 0.0

# %% [markdown]
# # Centrality

# %%
def pos_pass_list(pos):
    edges = []
    pass_action = ['pass', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 
                  'freekick_short', 'goalkick', 'corner_short']
    for i in range(len(pos)):
        play = pos[i]
        if play["type_name"] in pass_action:
            if play["result_name"] == 'success':
                try:
                    passer = play["player_name"]
                    receiver = pos[i+1]["player_name"]
                    edges.append((passer , receiver))
                except:
                    return edges
                
    return edges

# %%
passes = pos_pass_list(p_test)

# %%
def get_centrality(passes):
    G = nx.DiGraph((x, y, {'weight': v}) for (x, y), v in Counter(passes).items())
    #print(*G.edges(data=True), sep='\n')
    return nx.degree_centrality(G)

# %%
get_centrality(passes)
# Out:
# {'Antoine Griezmann': 0.6666666666666666,
#  'Raphaël Varane': 0.6666666666666666,
#  'Benjamin Pavard': 0.6666666666666666,
#  'Kylian Mbappé Lottin': 0.6666666666666666}

# %%
for pos in all_possessions:
    passes = pos_pass_list(pos)
    if len(passes) > 0:
        centrality = get_centrality(passes)
        for player in centrality.keys():
            game_centrality[player] = (game_centrality[player][0] + centrality[player], game_centrality[player][1] + 1)

# %%
for key in game_centrality.keys():
    pos_num = game_centrality[key][1]
    average_centrality = game_centrality[key][0] / pos_num if pos_num > 0 else 0
    #print(average_centrality)
    avg_centrality[key] = average_centrality
    #print(avg_centrality[key])

# %%
print(len(all_possessions))
# Out:
# 222

# %%
print(avg_centrality)
# Out:
# {'Antoine Griezmann': 0.5193678641047061, 'Raphaël Varane': 0.30856625258799175, 'Benjamin Pavard': 0.46934523809523815, 'Kylian Mbappé Lottin': 0.5008080808080807, 'Toby Alderweireld': 0.5619666048237477, 'Kevin De Bruyne': 0.4134114583333334, 'Blaise Matuidi': 0.4028730158730158, 'Jan Vertonghen': 0.34271825396825384, 'Paul Pogba': 0.46069182389937097, 'Axel Witsel': 0.3996787603930461, 'Samuel Yves Umtiti': 0.36633885438233266, 'Lucas Hernández Pi': 0.3990667254556143, 'N"Golo Kanté': 0.4879560011138957, 'Hugo Lloris': 0.15170401493930905, 'Olivier Giroud': 0.4163015873015873, 'Eden Hazard': 0.4191220238095239, 'Nacer Chadli': 0.4250163078930201, 'Moussa Sidi Yaya Dembélé': 0.2959473150962513, 'Marouane Fellaini-Bakkioui': 0.32310495626822155, 'Vincent Kompany': 0.5058965773809525, 'Thibaut Courtois': 0.1270913770913771, 'Romelu Lukaku Menama': 0.2114229024943311, 'Dries Mertens': 0.1996782496782497, 'Yannick Ferreira Carrasco': 0.059770114942528735, 'Steven N"Kemboanza Mike Christopher Nzonzi': 0.038461538461538464, 'Corentin Tolisso': 0.1261904761904762}

# %%
from collections import OrderedDict
dd = OrderedDict(sorted(avg_centrality.items(), key=lambda x: x[1], reverse=True))
for key in dd:
    print(key + ": " + str(dd[key]))
# Out:
# Toby Alderweireld: 0.5619666048237477
# Antoine Griezmann: 0.5193678641047061
# Vincent Kompany: 0.5058965773809525
# Kylian Mbappé Lottin: 0.5008080808080807
# N"Golo Kanté: 0.4879560011138957
# Benjamin Pavard: 0.46934523809523815
# Paul Pogba: 0.46069182389937097
# Nacer Chadli: 0.4250163078930201
# Eden Hazard: 0.4191220238095239
# Olivier Giroud: 0.4163015873015873
# Kevin De Bruyne: 0.4134114583333334
# Blaise Matuidi: 0.4028730158730158
# Axel Witsel: 0.3996787603930461
# Lucas Hernández Pi: 0.3990667254556143
# Samuel Yves Umtiti: 0.36633885438233266
# Jan Vertonghen: 0.34271825396825384
# Marouane Fellaini-Bakkioui: 0.32310495626822155
# Raphaël Varane: 0.30856625258799175
# Moussa Sidi Yaya Dembélé: 0.2959473150962513
# Romelu Lukaku Menama: 0.2114229024943311
# Dries Mertens: 0.1996782496782497
# Hugo Lloris: 0.15170401493930905
# Thibaut Courtois: 0.1270913770913771
# Corentin Tolisso: 0.1261904761904762
# Yannick Ferreira Carrasco: 0.059770114942528735
# Steven N"Kemboanza Mike Christopher Nzonzi: 0.038461538461538464

# %% [markdown]
# # Per Game

# %%
players = pd.read_hdf(spadl_h5,"players")
teams = pd.read_hdf(spadl_h5,"teams")
actiontypes = pd.read_hdf(spadl_h5, "actiontypes")
bodyparts = pd.read_hdf(spadl_h5, "bodyparts")
results = pd.read_hdf(spadl_h5, "results")

contribution = ['pass', 'dribble', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 'shot', 
                  'freekick_short', 'goalkick', 'corner_short', 'shot_penalty']

game = list(games.itertuples())[0]
#for game in tqdm.tqdm(list(games.itertuples()))[0]:
actions = pd.read_hdf(spadl_h5,f"actions/game_{game.game_id}")
actions = (
    actions.merge(actiontypes)
    .merge(results)
    .merge(bodyparts)
    .merge(players,"left",on="player_id")
    .merge(teams,"left",on="team_id")
    .sort_values(["period_id", "time_seconds", "timestamp"])
    .reset_index(drop=True)
)

all_possessions = []
curr_possession = []
possessing_team = actions.loc[0]["team_id"]
for i in range(len(actions)):
    action = actions.loc[i]["type_name"]
    action_team = actions.loc[i]["team_id"]
    result = actions.loc[i]["result_name"]
    if change_possession(action, action_team, possessing_team, result):
        possessing_team = action_team
        all_possessions.append(copy.deepcopy(curr_possession))
        curr_possession = []

    curr_possession.append(actions.loc[i])

game_centrality, team1, team2 = players_in_game(actions)

for pos in all_possessions:
    for pos in all_possessions:
        pos_players = players_in_pos(pos)

        for play in pos:
            if play['type_name'] == 'shot':
                for player in pos_players:
                    game_centrality[player][0] += 1

                if play['team_id'] == actions.loc[0]["team_id"]:
                    for player in team1:
                        game_centrality[player][1] += 1
                else:
                    for player in team2:
                        game_centrality[player][1] += 1

total_flow = {}
for player in players['player_name']:
    total_flow[player] = [0,0]
                    
for key in game_centrality.keys():
    total_flow[key][0] += game_centrality[key][0]
    total_flow[key][1] += game_centrality[key][1]
        
avg_flow = {}
for key in total_flow.keys():
        pos_num = total_flow[key][1]
        if pos_num > 0:
            avg_flow[key] = total_flow[key][0] / pos_num 
        
from collections import OrderedDict
dd = OrderedDict(sorted(avg_flow.items(), key=lambda x: x[1], reverse=True))
for key in dd:
    print(key + ": " + str(dd[key]))
# Out:
# Toby Alderweireld: 0.7777777777777778
# Antoine Griezmann: 0.7222222222222222
# Kylian Mbappé Lottin: 0.5555555555555556
# Olivier Giroud: 0.5555555555555556
# N"Golo Kanté: 0.5555555555555556
# Axel Witsel: 0.5555555555555556
# Vincent Kompany: 0.5555555555555556
# Paul Pogba: 0.5
# Blaise Matuidi: 0.4444444444444444
# Lucas Hernández Pi: 0.4444444444444444
# Kevin De Bruyne: 0.4444444444444444
# Eden Hazard: 0.4444444444444444
# Nacer Chadli: 0.4444444444444444
# Raphaël Varane: 0.3333333333333333
# Samuel Yves Umtiti: 0.3333333333333333
# Moussa Sidi Yaya Dembélé: 0.3333333333333333
# Jan Vertonghen: 0.3333333333333333
# Marouane Fellaini-Bakkioui: 0.3333333333333333
# Benjamin Pavard: 0.2777777777777778
# Dries Mertens: 0.2222222222222222
# Hugo Lloris: 0.1111111111111111
# Romelu Lukaku Menama: 0.1111111111111111
# Corentin Tolisso: 0.05555555555555555
# Thibaut Courtois: 0.0
# Steven N"Kemboanza Mike Christopher Nzonzi: 0.0
# Yannick Ferreira Carrasco: 0.0

# %%
players = pd.read_hdf(spadl_h5,"players")
teams = pd.read_hdf(spadl_h5,"teams")
actiontypes = pd.read_hdf(spadl_h5, "actiontypes")
bodyparts = pd.read_hdf(spadl_h5, "bodyparts")
results = pd.read_hdf(spadl_h5, "results")

total_flow = {}
for player in players['player_name']:
    total_flow[player] = [0,0]

contribution = ['pass', 'dribble', 'throw_in', 'corner_crossed', 'freekick_crossed', 'cross', 'shot', 
                  'freekick_short', 'goalkick', 'corner_short', 'shot_penalty']
    
for game in tqdm.tqdm(list(games.itertuples())):
    actions = pd.read_hdf(spadl_h5,f"actions/game_{game.game_id}")
    actions = (
        actions.merge(actiontypes)
        .merge(results)
        .merge(bodyparts)
        .merge(players,"left",on="player_id")
        .merge(teams,"left",on="team_id")
        .sort_values(["period_id", "time_seconds", "timestamp"])
        .reset_index(drop=True)
    )

    all_possessions = []
    curr_possession = []
    possessing_team = actions.loc[0]["team_id"]
    for i in range(len(actions)):
        action = actions.loc[i]["type_name"]
        action_team = actions.loc[i]["team_id"]
        result = actions.loc[i]["result_name"]
        if change_possession(action, action_team, possessing_team, result):
            possessing_team = action_team
            all_possessions.append(copy.deepcopy(curr_possession))
            curr_possession = []

        curr_possession.append(actions.loc[i])

    game_centrality, team1, team2 = players_in_game(actions)

    for pos in all_possessions:
        pos_players = []

        for play in pos:
            player = play['player_name']
            if play['type_name'] in contribution and play['result_name'] == 'success':
                if player not in pos_players:
                    pos_players.append(player)
            
            if play['type_name'] == 'shot':
                for player in pos_players:
                    game_centrality[player][0] += 1

                if play['team_id'] == actions.loc[0]["team_id"]:
                    for player in team1:
                        game_centrality[player][1] += 1
                else:
                    for player in team2:
                        game_centrality[player][1] += 1

    for key in game_centrality.keys():
        total_flow[key][0] += game_centrality[key][0]
        total_flow[key][1] += game_centrality[key][1]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 64/64 [01:36<00:00,  1.56s/it]

# %%
avg_flow = {}
for key in total_flow.keys():
        pos_num = total_flow[key][1]
        if pos_num >= 15:
            avg_flow[key] = total_flow[key][0] / pos_num 
        
from collections import OrderedDict
dd = OrderedDict(sorted(avg_flow.items(), key=lambda x: x[1], reverse=True))
for key in dd:
    print(key + ": " + str(dd[key]))
# Out:
# Lionel Andrés Messi Cuccittini: 0.7843137254901961
# Heung-Min Son: 0.78125
# Christian Alberto Cueva Bravo: 0.7096774193548387
# Toni Kroos: 0.6805555555555556
# Aaron Mooy: 0.6774193548387096
# Kieran Trippier: 0.6710526315789473
# Francisco Román Alarcón Suárez: 0.6470588235294118
# Rami Bedoui: 0.625
# Sung-Yeung Ki: 0.6190476190476191
# Sadio Mané: 0.6153846153846154
# Neymar da Silva Santos Junior: 0.6138613861386139
# Mesut Özil: 0.6111111111111112
# Edgar Yoel Bárcenas Herrera: 0.5909090909090909
# Kevin De Bruyne: 0.5842696629213483
# André Martín Carrillo Díaz: 0.5806451612903226
# Filipe Luis Kasmirski: 0.5757575757575758
# Philippe Coutinho Correia: 0.5643564356435643
# Hakim Ziyech: 0.5641025641025641
# Paul Pogba: 0.5573770491803278
# Wahbi Khazri: 0.5526315789473685
# Cristiano Ronaldo dos Santos Aveiro: 0.5510204081632653
# Carlos Alberto Vela Garrido: 0.55
# Shinji Kagawa: 0.5483870967741935
# Luka Modrić: 0.5462962962962963
# Xherdan Shaqiri: 0.5454545454545454
# Ali Maâloul: 0.5454545454545454
# Sergej Milinković-Savić: 0.5294117647058824
# Juan Guillermo Cuadrado Bello: 0.5263157894736842
# Mohamed Salah: 0.5217391304347826
# Eden Hazard: 0.5168539325842697
# Sergio Ramos García: 0.5147058823529411
# Javier Alejandro Mascherano: 0.5098039215686274
# Viktor Claesson: 0.5098039215686274
# Salman Mohammed Al Faraj: 0.5
# Gylfi Þór Sigurðsson: 0.5
# Renato Fabrizio Tapia Cortijo: 0.5
# Ellyes Skhiri: 0.5
# Ghilane Chalali: 0.5
# Edinson Roberto Cavani Gómez: 0.4888888888888889
# Younès Belhanda: 0.48717948717948717
# Luis Jan Piers Advíncula Castrillón: 0.4838709677419355
# Takashi Inui: 0.47619047619047616
# Gaku Shibasaki: 0.47619047619047616
# Yassine Meriah: 0.47368421052631576
# Eduardo Antonio Salvio: 0.47058823529411764
# Carlos Henrique Casimiro: 0.4666666666666667
# Ivan Rakitić: 0.46296296296296297
# M"Baye Babacar Niang: 0.46153846153846156
# Jorge Resurrección Merodio: 0.46
# Johann Berg Guðmunds­son: 0.4583333333333333
# Jordi Alba Ramos: 0.45588235294117646
# Yuto Nagatomo: 0.4523809523809524
# Mahmoud Ibrahim Hassan: 0.45161290322580644
# Gen Shōji: 0.45161290322580644
# Nicolás Alejandro Tagliafico: 0.45098039215686275
# Hirving Rodrigo Lozano Bahena: 0.45
# Cédric Ricardo Alves Soares: 0.4482758620689655
# Christian Dannemann Eriksen: 0.4473684210526316
# Ferjani Sassi: 0.4473684210526316
# Antoine Griezmann: 0.4444444444444444
# Kylian Mbappé Lottin: 0.4444444444444444
# N"Golo Kanté: 0.4444444444444444
# Guillermo Varela Olivera: 0.4444444444444444
# Jordan Brian Henderson: 0.4426229508196721
# Dušan Tadić: 0.4411764705882353
# Jae-Sung Lee: 0.4375
# Aymen Mathlouthi: 0.4375
# Mbark Boussoufa: 0.4358974358974359
# Salem Mohammed Al Dawsari: 0.43333333333333335
# Mohammed Al Burayk: 0.43333333333333335
# Oghenekaro Etebo: 0.43243243243243246
# Nicolás Hernán Otamendi: 0.43137254901960786
# Axel Witsel: 0.42696629213483145
# Thomas Meunier: 0.425
# Ismaïla Sarr: 0.4230769230769231
# Idrissa Gana Gueye: 0.4230769230769231
# Danilo Luiz da Silva: 0.42105263157894735
# Juan Fernando Quintero Paniagua: 0.42105263157894735
# Santiago Arias Naranjo: 0.42105263157894735
# Mathew Leckie: 0.41935483870967744
# Miguel Ángel Trauco Saavedra: 0.41935483870967744
# Granit Xhaka: 0.41818181818181815
# Miguel Arturo Layún Prado: 0.4166666666666667
# Héctor Miguel Herrera López: 0.4166666666666667
# Nabil Dirar: 0.4166666666666667
# Hussain Al Mogahwi: 0.4166666666666667
# Éver Maximiliano David Banega: 0.4146341463414634
# Thiago Alcântara do Nascimento: 0.41379310344827586
# Saîf-Eddine Khaoui: 0.4117647058823529
# José Luis Rodríguez Francis: 0.4090909090909091
# Gabriel Enrique Gómez Girón: 0.4090909090909091
# João Mário Naval da Costa Eduardo: 0.40816326530612246
# Raphaël Adelino José Guerreiro: 0.40816326530612246
# William Silva de Carvalho: 0.40816326530612246
# Celso Borges Mora: 0.4074074074074074
# Jefferson Agustín Farfán Guadalupe: 0.4074074074074074
# Ahmed Musa: 0.40540540540540543
# Yūya Ōsako: 0.40476190476190477
# Luis Alberto Suárez Díaz: 0.4
# Roman Zobnin: 0.4
# Phil Jones: 0.4
# Sergio Busquets i Burgos: 0.39705882352941174
# Gerard Piqué Bernabéu: 0.39705882352941174
# Jesse Lingard: 0.39473684210526316
# Anice Badri: 0.39473684210526316
# Duško Tošić: 0.391304347826087
# Branislav Ivanović: 0.391304347826087
# Joshua Kimmich: 0.3888888888888889
# İlkay Gündoğan: 0.3888888888888889
# Trent Sainsbury: 0.3870967741935484
# Josh Risdon: 0.3870967741935484
# Mark Milligan: 0.3870967741935484
# Mile Jedinak: 0.3870967741935484
# Tom Rogić: 0.3870967741935484
# Sergio Leonel Agüero del Castillo: 0.38636363636363635
# Nordin Amrabat: 0.38461538461538464
# David Josué Jiménez Silva: 0.38235294117647056
# Min-Woo Kim: 0.38095238095238093
# Maya Yoshida: 0.38095238095238093
# Onyinye Wilfred Ndidi: 0.3783783783783784
# Aron Einar Gunnarsson: 0.375
# Oussama Haddadi: 0.375
# Marcelo Vieira da Silva Júnior: 0.37349397590361444
# Maximiliano Eduardo Meza: 0.37254901960784315
# Jérôme Boateng: 0.37209302325581395
# Harry Maguire: 0.37209302325581395
# Radamel Falcao García Zárate: 0.3684210526315789
# Fakhreddine Ben Youssef: 0.3684210526315789
# Sardar Azmoun: 0.3684210526315789
# Andrés Iniesta Luján: 0.36764705882352944
# Kléper Laveran Lima Ferreira: 0.3673469387755102
# José Miguel da Rocha Fonte: 0.3673469387755102
# Javier Hernández Balcázar: 0.36666666666666664
# Hamdi Nagguez: 0.36363636363636365
# Karim El Ahmadi Al Aroos: 0.358974358974359
# Aziz Eraltay Behich: 0.3548387096774194
# Édison Michael Flores Peralta: 0.3548387096774194
# Víctor Yoshimar Yotún Flores: 0.3548387096774194
# Christian Guillermo Martín Ramos Garagay: 0.3548387096774194
# Genki Haraguchi: 0.3548387096774194
# Nicolai Jørgensen: 0.35294117647058826
# Marcus Berg: 0.35294117647058826
# Victor Moses: 0.35135135135135137
# John Michael Nchekwube Obinna: 0.35135135135135137
# Šime Vrsaljko: 0.35051546391752575
# José Andrés Guardado Hernández: 0.35
# Ricardo Domingos Barbosa Pereira: 0.35
# Julian Draxler: 0.3488372093023256
# Raphaël Varane: 0.3472222222222222
# Lucas Hernández Pi: 0.3472222222222222
# Marco Reus: 0.3472222222222222
# Thorgan Hazard: 0.34615384615384615
# Moussa Wagué: 0.34615384615384615
# José Martín Cáceres Silva: 0.34545454545454546
# Ricardo Iván Rodríguez Araya: 0.34545454545454546
# Ashley Young: 0.3442622950819672
# Grzegorz Krychowiak: 0.34375
# Jan Bednarek: 0.34375
# Robert Lewandowski: 0.34375
# Wílmar Enrique Barrios Terán: 0.34285714285714286
# José Ignacio Fernández Iglesias: 0.34285714285714286
# Steven Zuber: 0.34146341463414637
# James David Rodríguez Rubio: 0.3333333333333333
# Abdullah Ibrahim Otayf: 0.3333333333333333
# Blaise Matuidi: 0.3333333333333333
# Cristian Gamboa Luna: 0.3333333333333333
# Sebastian Larsson: 0.3333333333333333
# Michał Pazdan: 0.3333333333333333
# Maciej Rybus: 0.3333333333333333
# Adrien Sebastian Perruchet Silva: 0.3333333333333333
# Achraf Hakimi Mouh: 0.3333333333333333
# Gabriel Iván Mercado: 0.3333333333333333
# Michy Batshuayi Tunga: 0.3333333333333333
# Se-Jong Ju: 0.3333333333333333
# Takashi Usami: 0.3333333333333333
# Raheem Shaquille Sterling: 0.32894736842105265
# Douglas Costa de Souza: 0.32653061224489793
# Lasse Schöne: 0.3235294117647059
# Nemanja Matić: 0.3235294117647059
# Abdalla Mahmoud El Said Bekhit: 0.3225806451612903
# Medhi Amine El Mouttaqi Benatia: 0.3225806451612903
# Aleksandr Samedov: 0.32
# Faustino Marcos Alberto Rojo: 0.3170731707317073
# Johan Andrés Mojica Palacio: 0.3157894736842105
# Thomas Delaney: 0.3157894736842105
# Naïm Sliti: 0.3157894736842105
# Ivan Perišić: 0.3148148148148148
# Alfreð Finnbogason: 0.3125
# Kamil Grosicki: 0.3125
# Tyronne Ebuehi: 0.3125
# Makoto Hasebe: 0.30952380952380953
# Domagoj Vida: 0.30927835051546393
# Matías Vecino Falero: 0.3090909090909091
# Diego da Silva Costa: 0.3088235294117647
# Nacer Chadli: 0.30864197530864196
# Youssouf Sabaly: 0.3076923076923077
# Willian Borges da Silva: 0.3069306930693069
# Olivier Giroud: 0.3055555555555556
# Thomas Müller: 0.3055555555555556
# Joel Nathaniel Campbell Samuels: 0.30434782608695654
# Romain Saïss: 0.30434782608695654
# Dries Mertens: 0.3020833333333333
# Mário Figueira Fernandes: 0.3
# Artem Dzyuba: 0.3
# Yasir Gharsan Al Shahrani: 0.3
# Kelechi Promise Iheanacho: 0.2972972972972973
# Thiago Emiliano da Silva: 0.297029702970297
# Enzo Nicolás Pérez: 0.2962962962962963
# Mats Hummels: 0.2962962962962963
# Youri Tielemans: 0.2962962962962963
# Seon-Min Moon: 0.2962962962962963
# Samuel Yves Umtiti: 0.29508196721311475
# Aleksandar Mitrović: 0.29411764705882354
# Aleksandar Kolarov: 0.29411764705882354
# Ola Toivonen: 0.29411764705882354
# Bryan Oviedo: 0.29411764705882354
# Fágner Conserva Lemos: 0.2926829268292683
# Toby Alderweireld: 0.29213483146067415
# Lucas Rodrigo Biglia: 0.2916666666666667
# Jens Stryger Larsen: 0.2916666666666667
# Timo Werner: 0.2916666666666667
# Anga Dedryck Boyata: 0.2916666666666667
# Rodrigo Bentancur Colmán: 0.2909090909090909
# Mohamed Abdul Shafy Sayed Abouezeid: 0.2903225806451613
# Vincent Kompany: 0.2898550724637681
# Harry Kane: 0.2894736842105263
# Mario Mandžukić: 0.28865979381443296
# Łukasz Piszczek: 0.2857142857142857
# Wojciech Szczęsny: 0.2857142857142857
# Carlos Joel Salcedo Hernández: 0.2833333333333333
# Denis Cheryshev: 0.28
# John Stones: 0.27906976744186046
# Benjamin Pavard: 0.2786885245901639
# Kyle Walker: 0.2786885245901639
# Marcelo Brozović: 0.27835051546391754
# Dejan Lovren: 0.2777777777777778
# Andrej Kramarić: 0.2777777777777778
# João Filipe Iria Santos Moutinho: 0.27586206896551724
# Niklas Süle: 0.27586206896551724
# Antonio Rukavina: 0.2727272727272727
# Jacek Góralski: 0.2727272727272727
# Jan Vertonghen: 0.2696629213483146
# Romelu Lukaku Menama: 0.2696629213483146
# Amine Harit: 0.26666666666666666
# Bernardo Mota Veiga de Carvalho e Silva: 0.2653061224489796
# Gonçalo Manuel Ganchinho Guedes: 0.2653061224489796
# Daniel Carvajal Ramos: 0.2631578947368421
# Pione Sisto Ifolo Emirmija: 0.2631578947368421
# Omid Ebrahimi: 0.2631578947368421
# Karim Ansarifard: 0.2631578947368421
# Ramin Rezaeian: 0.2631578947368421
# Alireza Jahanbakhsh: 0.2631578947368421
# Vahid Amiri: 0.2631578947368421
# Marouane Fellaini-Bakkioui: 0.2625
# Hiroki Sakai: 0.2619047619047619
# Aleksandr Golovin: 0.2608695652173913
# Daniel Colindres Solera: 0.2608695652173913
# Moussa Sidi Yaya Dembélé: 0.2608695652173913
# Mohamed Naser Elsayed Elneny: 0.25806451612903225
# Ahmed Fathy Abdel Meneim Ibrahim: 0.25806451612903225
# Fabian Lukas Schär: 0.2564102564102564
# José María Giménez de Vargas: 0.2558139534883721
# Albin Ekdal: 0.2549019607843137
# Blerim Džemaili: 0.2545454545454545
# Piotr Zieliński: 0.25
# Khalid Boutaïb: 0.25
# Ricardo Guardia Avila: 0.25
# Ricardo Andrade Quaresma Bernardo: 0.25
# João Miranda de Souza Filho: 0.24752475247524752
# Ivan Strinić: 0.24742268041237114
# Ante Rebić: 0.24742268041237114
# Ángel Fabián Di María Hernández: 0.24390243902439024
# Carlos Andrés Sánchez Arcosa: 0.24242424242424243
# Yannick Ferreira Carrasco: 0.23943661971830985
# Fabian Delph: 0.2391304347826087
# Jefferson Andrés Lerma Solís: 0.23684210526315788
# Henrik Dalsgaard: 0.23684210526315788
# Diego Roberto Godín Leal: 0.23636363636363636
# Manuel Obafemi Akanji: 0.23636363636363636
# Yussuf Yurary Poulsen: 0.23529411764705882
# Ludwig Augustinsson: 0.23529411764705882
# Emil Forsberg: 0.23529411764705882
# Luis Fernando Muriel Fruto: 0.23529411764705882
# Salif Sané: 0.23076923076923078
# Eric Dier: 0.22950819672131148
# Román Aureliano Torres Morcillo: 0.22727272727272727
# Mikael Lustig: 0.22727272727272727
# Marco Jhonfai Fabián De La Mora: 0.22727272727272727
# José Paolo Guerrero González: 0.22580645161290322
# Tarek Hamed: 0.22580645161290322
# Danny Rose: 0.22413793103448276
# David Alberto Guzmán Pérez: 0.2222222222222222
# Antonio Rüdiger: 0.2222222222222222
# Gonzalo Gerardo Higuaín: 0.21951219512195122
# Ousmane Dembélé: 0.21951219512195122
# Young-Gwon Kim: 0.21875
# Hee-Chan Hwang: 0.21875
# Edson Omar Álvarez Velázquez: 0.21666666666666667
# William Troost-Ekong: 0.21621621621621623
# Leon-Aderemi Balogun: 0.21621621621621623
# Simon Thorup Kjær: 0.21052631578947367
# Davinson Sánchez Mina: 0.21052631578947367
# Jordan Pickford: 0.20930232558139536
# Fernando Luiz Rosa: 0.2079207920792079
# Yerry Fernando Mina González: 0.20689655172413793
# Nikola Milenković: 0.20588235294117646
# Stephan Lichtsteiner: 0.20512820512820512
# Josip Pivarić: 0.2028985507246377
# Daler Kuzyaev: 0.2
# Fyodor Smolov: 0.2
# Hattan Babhir: 0.2
# Corentin Tolisso: 0.2
# Valon Behrami: 0.2
# Hugo Ayala Castro: 0.2
# Anderson Santamaría Bardales: 0.2
# Gabriel Fernando de Jesus: 0.19801980198019803
# Andreas Granqvist: 0.19607843137254902
# Héctor Alfredo Moreno Herrera: 0.1956521739130435
# Thibaut Courtois: 0.1941747572815534
# Bamidele Alli: 0.19402985074626866
# Mathew Ryan: 0.1935483870967742
# Marwan Mohsen: 0.1935483870967742
# Amr Medhat Warda: 0.1935483870967742
# Keisuke Honda: 0.1935483870967742
# Lucas Vázquez Iglesias: 0.19230769230769232
# Alan Dzagoev: 0.19230769230769232
# Giorgian Daniel De Arrascaeta Benedetti: 0.19230769230769232
# Jonas Hector: 0.19148936170212766
# Seung-Woo Lee: 0.19047619047619047
# Aleksandr Erokhin: 0.19047619047619047
# Iago Aspas Juncal: 0.18867924528301888
# Cristhian Ricardo Stuani Curbelo: 0.1875
# Yong Lee: 0.1875
# Bartosz Bereszyński: 0.1875
# Bruno Miguel Borges Fernandes: 0.1875
# Abdiel Arroyo Molinar: 0.1875
# Mateo Kovačić: 0.18571428571428572
# Bryan Ruiz González: 0.18518518518518517
# Rui Pedro dos Santos Patrício: 0.1836734693877551
# Jesús Daniel Gallardo Vasconcelos: 0.18333333333333332
# Aníbal Cesis Godoy: 0.18181818181818182
# Dylan Bronn: 0.18181818181818182
# Ilya Kutepov: 0.18
# Ruben Loftus-Cheek: 0.18
# Cristian David Pavón: 0.17647058823529413
# Rúrik Gíslason: 0.17647058823529413
# Kári Árnason: 0.17647058823529413
# Adem Ljajić: 0.17647058823529413
# Motaz Ali Hassan Hawsawi: 0.17647058823529413
# Marco Asensio Willemsen: 0.17543859649122806
# Roberto Firmino Barbosa de Oliveira: 0.1744186046511628
# Steven N"Kemboanza Mike Christopher Nzonzi: 0.17391304347826086
# Luka Milivojević: 0.17391304347826086
# Andrés Mateus Uribe Villa: 0.1724137931034483
# José Paulo Bezzera Maciel Júnior: 0.16831683168316833
# Josip Drmic: 0.16666666666666666
# Cristian Gabriel Rodríguez Barrotti: 0.16363636363636364
# Nahitan Michel Nández Acosta: 0.16363636363636364
# Daniel Arzani: 0.16129032258064516
# Sergei Ignashevich: 0.16
# Andreas Christensen: 0.15789473684210525
# Mehdi Taremi: 0.15789473684210525
# Saman Ghoddos: 0.15789473684210525
# Robin Olsen: 0.1568627450980392
# Birkir Bjarnason: 0.15625
# Woo-Young Jung: 0.15625
# Marcus Rashford: 0.15584415584415584
# Danijel Subašić: 0.15463917525773196
# Kalidou Koulibaly: 0.15384615384615385
# Milan Badelj: 0.15384615384615385
# Julian Brandt: 0.1527777777777778
# Manuel Neuer: 0.1527777777777778
# Yuri Zhirkov: 0.15151515151515152
# Manuel Henrique Tavares Fernandes: 0.15
# Giancarlo González Castro: 0.14814814814814814
# Filip Kostić: 0.14705882352941177
# Lucas Torreira Di Pascua: 0.14545454545454545
# Yury Gazinskiy: 0.14285714285714285
# Mathias Jattah-Njie Jørgensen: 0.14285714285714285
# Dawid Kownacki: 0.14285714285714285
# Jesús Manuel Corona Ruíz: 0.14285714285714285
# Victor Nilsson Lindelöf: 0.1388888888888889
# Fidel Escobar Mendieta: 0.13636363636363635
# Syam Ben Youssef: 0.13636363636363635
# Brian Oladapo Idowu: 0.13513513513513514
# Michael Lang: 0.13513513513513514
# Fedor Kudryashov: 0.13513513513513514
# Hugo Lloris: 0.13114754098360656
# Yehya Sulaiman Al Shehri: 0.13043478260869565
# Robbie Kruse: 0.12903225806451613
# Pedro Jesús Aquino Sánchez: 0.12903225806451613
# Manuel Marouan da Costa Trinidade: 0.1282051282051282
# Breel-Donald Embolo: 0.12727272727272726
# Thomas Vermaelen: 0.125
# Fayçal Fajr: 0.125
# Hörður Björgvin Magnússon: 0.125
# Emil Hallfreðsson: 0.125
# Hyun-Soo Jang: 0.125
# Mario Gavranović: 0.125
# Diego Sebastián Laxalt Suárez: 0.12195121951219512
# Raúl Alonso Jiménez Rodríguez: 0.12
# Marvin Plattenhardt: 0.12
# Andrew Nabbout: 0.11764705882352941
# Carlos Alberto Sánchez Moreno: 0.11538461538461539
# Cheikhou Kouyaté: 0.11538461538461539
# Carlos Arturo Bacca Ahumada: 0.11428571428571428
# Johnny Acosta Zamora: 0.1111111111111111
# Sebastian Rudy: 0.1111111111111111
# Yann Sommer: 0.10909090909090909
# Odion Jude Ighalo: 0.10810810810810811
# Alex Iwobi: 0.10810810810810811
# Marko Pjaca: 0.10810810810810811
# Gustav Svensson: 0.10810810810810811
# Andreas Evald Cornelius: 0.10714285714285714
# Kasper Schmeichel: 0.10526315789473684
# Martin Braithwaite Christensen: 0.10526315789473684
# Morteza Pouraliganji: 0.10526315789473684
# Seyed Majid Hosseini: 0.10526315789473684
# Osama Abdulrezag Hawsawi: 0.1
# Fahad Mosaed Al Muwallad Al Harbi: 0.1
# Renato Soares de Oliveira Augusto: 0.1
# André Miguel Valente Silva: 0.1
# Ahmed Hegazi: 0.0967741935483871
# Ali Gabr: 0.0967741935483871
# Hyun-Woo Cho: 0.09375
# Sami Khedira: 0.09259259259259259
# Nabil Fekir: 0.09259259259259259
# Farouk Ben Mustapha: 0.09090909090909091
# Pontus Jansson: 0.09090909090909091
# Kamil Glik: 0.09090909090909091
# Wilfredo Daniel Caballero: 0.08823529411764706
# Mohamed El Shenawy: 0.08695652173913043
# Kenneth Josiah Omeruo: 0.08695652173913043
# Sverrir Ingi Ingason: 0.08695652173913043
# Aziz Bouhaddouz: 0.08695652173913043
# Hotaru Yamaguchi: 0.08571428571428572
# Mario Gómez García: 0.08333333333333333
# Rafael Márquez Álvarez: 0.07894736842105263
# David Ospina Ramírez: 0.07894736842105263
# Khadim N"Diaye: 0.07692307692307693
# Alberto Junior Rodríguez Valdelomar: 0.07407407407407407
# Néstor Fernando Muslera Micol: 0.07272727272727272
# Rodrigo Moreno Machado: 0.07017543859649122
# Jamie Vardy: 0.06976744186046512
# Alisson Ramsés Becker: 0.06930693069306931
# Leon Goretzka: 0.06896551724137931
# Sofyan Amrabat: 0.06666666666666667
# Birkir Már Sævarsson: 0.0625
# Ja-Cheol Koo: 0.0625
# Emil Krafth: 0.0625
# Igor Akinfeev: 0.06
# Vladimir Stojković: 0.058823529411764705
# Ari Freyr Skúlason: 0.058823529411764705
# Yasser Abdullah Al Mosailem: 0.058823529411764705
# Franco Armani: 0.058823529411764705
# Ehsan Hajsafi: 0.05263157894736842
# Alfred John Momar N"Diaye: 0.05
# Mame Biram Diouf: 0.05
# Cheikh N"Doye: 0.05
# Denis Lemi Zakaria Lako Lado: 0.047619047619047616
# Eiji Kawashima: 0.047619047619047616
# Vedran Ćorluka: 0.047619047619047616
# Jaime Manuel Penedo Cano: 0.045454545454545456
# Nemanja Radonjić: 0.043478260869565216
# Chul Hong: 0.037037037037037035
# Jackson Irvine: 0.03225806451612903
# Tomi Jurić: 0.03225806451612903
# Pedro David Gallese Quiróz: 0.03225806451612903
# Ramadan Sobhi: 0.03225806451612903
# Mahmoud Abdul Monem Abdelhamid Soliman: 0.03225806451612903
# Shinji Okazaki: 0.03225806451612903
# Ayoub El Kaabi: 0.03225806451612903
# Hannes Þór Halldórsson: 0.03125
# Ragnar Sigurðsson: 0.03125
# David de Gea Quintana: 0.029411764705882353
# Munir Mohand Mohamedi: 0.02564102564102564
# Haris Seferović: 0.024390243902439025
# Keylor Navas Gamboa: 0.0
# Mohanad Aseri Abu Radiah: 0.0
# Francis Odinaka Uzoho: 0.0
# Simeon Tochukwu Nwankwo: 0.0
# Björn Bergmann Sigurðarson: 0.0
# Raúl Mario Ruidíaz Misitich: 0.0
# Francisco Guillermo Ochoa Magaña: 0.0
# Oscar Hiljemark: 0.0
# Isaac Kiese Thelin: 0.0
# Mehdi Carcela-González: 0.0
# Alireza Safar Beiranvand: 0.0
# Yohan Benalouane: 0.0
# Łukasz Teodorczyk: 0.0
# Maximiliano Gómez González: 0.0
# Arnór Ingvi Traustason: 0.0
# Albert Gudmundsson: 0.0
# Oribe Peralta Morones: 0.0
# Bassem Srarfi: 0.0
# Ahmed Khalil: 0.0
# Marcos Aoás Corrêa : 0.0
# Johan Danon Djourou-Gbadjere: 0.0
# Martin Olsson: 0.0

# %%
print(total_flow["Heung-Min Son"])
# Out:
# [25, 32]
